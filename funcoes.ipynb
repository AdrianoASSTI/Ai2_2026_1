# %%
def ola_mundo():
    print("Ola, Mundo!")

ola_mundo()
# Out:
# Ola, Mundo!

# %%
def funcaoDois(nome):
    print ('Ola %s!' %(nome))

funcaoDois(input("Digite seu nome: "))
# Out:
# Ola Adriano!

# %%
def funcLeitura(): #1
    for i in range(0, 5): #2
        print ("Número " + str(i)) #3

funcLeitura()

# %%
def funcSequencia(): #1
    for i in range(0, 5): #2
        print ('linha ' + str(i+1)) #3

funcSequencia()

# %%
import statistics #1

def notas(): #2
    n1 = float(input("Digite a primeira nota: "))
    n2 = float(input("Digite a segunda nota: "))
    n3 = float(input("Digite a terceira nota: "))
    n4 = float(input("Digite a quarta nota: "))
    
    entradas = [n1, n2, n3, n4] #4
    
    media = round(statistics.mean(entradas), 2)#5
    
    print (f'Sua nota 1 é {n1}')
    print (f'Sua nota 2 é {n2}')
    print (f'Sua nota 3 é {n3}')
    print (f'Sua nota 4 é {n4}')
    print (f'Sua média é {media}') 

    if media < 4:
        print("Você está Reprovado")
    elif media < 6:
        print("Você está em Recuperação")
    else:
        print("Você está Aprovado")
    
    return media

notas()
# Out:
# Sua nota 1 é 8.0
# Sua nota 2 é 8.0
# Sua nota 3 é 8.0
# Sua nota 4 é 8.0
# Sua média é 8.0
# Você está Aprovado
# 8.0

# %%
var_global = 10


def multiplica():
    num1= int(input("Digite um número 1: "))
    num2= int(input("Digite um número 2: "))
    
    var_local =num1 * num2
    
    print (var_local)
    
    return var_local
    
multiplica()
# Out:
# 200
# 200
